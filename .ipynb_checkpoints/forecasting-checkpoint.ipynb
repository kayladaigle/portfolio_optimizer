# %%
import pandas as pd

# %%
import warnings
warnings.simplefilter('ignore')

# %%
from data_processing import returns

# %%
returns
# Out:
#            Date       AGG       BIL       BND       EDV       IEF       IEI  \
# 0    2014-12-08       NaN       NaN       NaN       NaN       NaN       NaN
# 1    2014-12-09  0.001547 -0.000219  0.000364  0.006597  0.003698  0.001965
# 2    2014-12-10  0.001726  0.000000  0.002667  0.010867  0.004535  0.003023
# 3    2014-12-11 -0.000363  0.000000 -0.000967  0.004760 -0.001693 -0.001874
# 4    2014-12-12  0.003176  0.000219  0.003389  0.020990  0.008197  0.004162
# ...         ...       ...       ...       ...       ...       ...       ...
# 2508 2024-11-25  0.008997  0.000109  0.009230  0.037277  0.010791  0.005864
# 2509 2024-11-26 -0.001520  0.000000 -0.001775 -0.004340 -0.002114 -0.000686
# 2510 2024-11-27  0.002740  0.000327  0.002735  0.009398  0.004025  0.002574
# 2511 2024-11-29  0.003947  0.000218  0.003682  0.013493  0.004220  0.002310
# 2512 2024-12-02 -0.003024 -0.003378 -0.002446  0.005192 -0.003152 -0.002988
#
# ...

# %%
# change to long format to prepare for prophet modeling
long_format = returns.melt(id_vars=['Date'],
                           var_name = 'Stock',
                           value_name = 'Return')

# %%
long_format
# Out:
#              Date Stock    Return
# 0      2014-12-08   AGG       NaN
# 1      2014-12-09   AGG  0.001547
# 2      2014-12-10   AGG  0.001726
# 3      2014-12-11   AGG -0.000363
# 4      2014-12-12   AGG  0.003176
# ...           ...   ...       ...
# 118106 2024-11-25   XLK -0.000043
# 118107 2024-11-26   XLK  0.005009
# 118108 2024-11-27   XLK -0.013546
# 118109 2024-11-29   XLK  0.009284
# 118110 2024-12-02   XLK  0.009498
#
# [118111 rows x 3 columns]

# %%
# rename to match compatibility with prophet 
long_format.rename(columns= {'Date':'ds','Return':'y'},inplace=True)

# %%
long_format
# Out:
#                ds Stock         y
# 0      2014-12-08   AGG       NaN
# 1      2014-12-09   AGG  0.001547
# 2      2014-12-10   AGG  0.001726
# 3      2014-12-11   AGG -0.000363
# 4      2014-12-12   AGG  0.003176
# ...           ...   ...       ...
# 118106 2024-11-25   XLK -0.000043
# 118107 2024-11-26   XLK  0.005009
# 118108 2024-11-27   XLK -0.013546
# 118109 2024-11-29   XLK  0.009284
# 118110 2024-12-02   XLK  0.009498
#
# [118111 rows x 3 columns]

# %%
# place each stock in groups
stock_groups = {stock:group[['ds','y']] for stock, group in long_format.groupby('Stock')}

# %%
stock_groups['AGG']
# Out:
#              ds         y
# 0    2014-12-08       NaN
# 1    2014-12-09  0.001547
# 2    2014-12-10  0.001726
# 3    2014-12-11 -0.000363
# 4    2014-12-12  0.003176
# ...         ...       ...
# 2508 2024-11-25  0.008997
# 2509 2024-11-26 -0.001520
# 2510 2024-11-27  0.002740
# 2511 2024-11-29  0.003947
# 2512 2024-12-02 -0.003024
#
# [2513 rows x 2 columns]

# %%
from prophet import Prophet

# %%
# loop through stocks to get future predictions on each stock
def forecast_returns(stock_groups):
    forecasts = {}
    
    five_years = 365 * 5
    
    for stock, data in stock_groups.items():
        model = Prophet()
        model.fit(data)
        futureFiveYears = model.make_future_dataframe(periods=five_years)  # Forecasting 5 years ahead
        forecast = model.predict(futureFiveYears)
    
        forecasts[stock] = forecast[['ds', 'yhat']] 
    
    return forecasts

# %%
forecasts = forecast_returns(stock_groups)
# Out:
# 15:57:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:57:45 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %%
forecasts['AMZN']
# Out:
#              ds      yhat
# 0    2014-12-08 -0.000586
# 1    2014-12-09 -0.000005
# 2    2014-12-10  0.000056
# 3    2014-12-11 -0.000395
# 4    2014-12-12 -0.001600
# ...         ...       ...
# 4333 2029-11-27  0.001318
# 4334 2029-11-28  0.001158
# 4335 2029-11-29  0.000448
# 4336 2029-11-30 -0.001048
# 4337 2029-12-01  0.009647
#
# [4338 rows x 2 columns]

# %%
# forecast sent to CSV for optimization
forecast_df = pd.concat(forecasts.values(), keys = forecasts.keys())

# %%
forecast_df.to_csv('forecasted_five_year_returns.csv')

# %%
# for model testing, cross-validation
from prophet.diagnostics import cross_validation, performance_metrics

# %%
def evaluation_model(stock_groups):
    evaluation_results = {}

    for stock, data in stock_groups.items():
        data_length = len(data)
        print(f"Data length for {stock}: {data_length} days") 

    for stock, data in stock_groups.items():
    
        
        model = Prophet()
        model.fit(data)

        df_cv = cross_validation(model, initial = '180 days', period = '60 days', horizon ='90 days')

        df_p = performance_metrics(df_cv)

        evaluation_results[stock]= df_p

    return evaluation_results

# %%
evaluation_results = evaluation_model(stock_groups)
# Out:
# 16:08:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:08:22 - cmdstanpy - INFO - Chain [1] done processing
# Data length for AAPL: 2513 days
# Data length for AGG: 2513 days
# Data length for AMZN: 2513 days
# Data length for BIL: 2513 days
# Data length for BND: 2513 days
# Data length for EDV: 2513 days
# Data length for GLD: 2513 days
# Data length for GOOGL: 2513 days
# Data length for IBIT: 2513 days
# Data length for IEF: 2513 days
# Data length for IEFA: 2513 days
# Data length for IEI: 2513 days
# Data length for IEMG: 2513 days
# Data length for IJH: 2513 days
# Data length for IJR: 2513 days
# Data length for IVV: 2513 days
# Data length for IWF: 2513 days
# Data length for IWM: 2513 days
# Data length for META: 2513 days
# Data length for MSFT: 2513 days
# Data length for NVDA: 2513 days
# Data length for QQQ: 2513 days
# Data length for RSP: 2513 days
# Data length for SCHD: 2513 days
# Data length for SGOV: 2513 days
# Data length for SHV: 2513 days
# ...

# %%
evaluation_results
# Out:
# {'AAPL':    horizon       mse      rmse       mae     mdape     smape  coverage
#  0   9 days  0.000344  0.018543  0.012805  0.997730  1.548180  0.838600
#  1  10 days  0.000329  0.018126  0.012358  0.996284  1.526026  0.850480
#  2  11 days  0.000370  0.019235  0.012943  0.996284  1.531738  0.842210
#  3  12 days  0.000382  0.019536  0.013225  0.995589  1.534141  0.830028
#  4  13 days  0.000358  0.018927  0.013074  0.995589  1.534259  0.821530
#  ..     ...       ...       ...       ...       ...       ...       ...
#  77 86 days  0.000304  0.017423  0.012773  1.083583  1.626272  0.802114
#  78 87 days  0.000329  0.018151  0.013538  1.090831  1.664757  0.793201
#  79 88 days  0.000372  0.019285  0.014092  1.090831  1.665784  0.788456
#  80 89 days  0.000385  0.019619  0.014146  1.079785  1.636115  0.794509
#  81 90 days  0.000444  0.021077  0.014905  1.045797  1.632755  0.781870
#
#  [82 rows x 7 columns],
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


evaluation_df = pd.concat(evaluation_results, ignore_index=True)
evaluation_df
# Out:
#      horizon       mse      rmse       mae     mdape     smape  coverage
# 0     9 days  0.000344  0.018543  0.012805  0.997730  1.548180  0.838600
# 1    10 days  0.000329  0.018126  0.012358  0.996284  1.526026  0.850480
# 2    11 days  0.000370  0.019235  0.012943  0.996284  1.531738  0.842210
# 3    12 days  0.000382  0.019536  0.013225  0.995589  1.534141  0.830028
# 4    13 days  0.000358  0.018927  0.013074  0.995589  1.534259  0.821530
# ...      ...       ...       ...       ...       ...       ...       ...
# 3825 86 days  0.000193  0.013883  0.010086  1.023153  1.635007  0.776964
# 3826 87 days  0.000210  0.014502  0.010451  1.019886  1.634406  0.773371
# 3827 88 days  0.000215  0.014673  0.010630  1.028368  1.659541  0.763598
# 3828 89 days  0.000216  0.014690  0.010571  1.023435  1.634910  0.768795
# 3829 90 days  0.000246  0.015697  0.011221  1.016580  1.642129  0.756374
#
# [3830 rows x 7 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='horizon', y='rmse', data=evaluation_df, marker='o', label='RMSE')
sns.lineplot(x='horizon', y='mae', data=evaluation_df, marker='o', label='MAE')
plt.title('RMSE and MAE across Horizons for AAPL')
plt.xlabel('Forecast Horizon')
plt.ylabel('Error')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
